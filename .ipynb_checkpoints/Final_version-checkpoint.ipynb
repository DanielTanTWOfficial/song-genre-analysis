# %% [markdown]
# ## SC1015 Project
#
# Why are some songs more popular than others? What makes a song popular? In this project, we utilize the Song Popularity Dataset on Kaggle to find out if the popularity of a song can be determined by acoustic data such as acousticness, danceability, liveliness and energy.
#
# We aim to:
# 1. Accurately predict how popular songs are/will be based upon their characteristics. (Testing on songs in the Spotify Music Dataset)
# 2. Demonstrate how relevant our predictions are in real life by predicting the popularity of songs on the Billboard top 100 and checking whether their popularity is reflected y the predictions of our model.

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb
sb.set()

# %%
# only if running on Google Colab
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# Create a dataframe from the dataset

# %%
#songdata = pd.read_csv('data/knn_songs.csv', index_col=0)
#songdata = pd.read_csv('data/genre_music.csv')
songdata = pd.read_csv('data/genre_music.csv')
songdata = songdata.sort_values(['track'])
#songdata = songdata.sort_values(["decade"], ascending = (False))
songdata.head(20)
# Out:
#                                                    track  \
# 11343            ""Cherry Cherry"" from Hot August Night
# 4669                                  ""Come, Sleep...""
# 21253         ""I'll Be Back"" / Police Station & Escape
# 39054                 ""Is This My Fate,"" He Asked Them
# 15187                            ""Jerry"" To The Rescue
# 2495                      ""Joseph, lieber Joseph mein""
# 6039                               ""Móvil"" Oil Special
# 4877   ""Tragic"" Overture, Op. 81: Allegro ma non tr...
# 34927                                     $ave Dat Money
# 6348                                        ' Cello Song
# 4712                ''Bang Bang'' (My Baby Shot Me Down)
# 34500                                 '03 Bonnie & Clyde
# 23011                                    '65 Love Affair
# 5876                      'Angels We Have Heard On High'
# 14051                                'Buked and Scorned'
# 13562                                'Buked and Scorned'
# 6571                                    'Deck The Halls'
# 4509                                  'Joy To The World'
# 10697                              'Round About Midnight
# 5630                                     'Round Midnight
#
#                                                 artist  danceability   energy  \
# 11343                                     Neil Diamond         0.341  0.94800
# 4669                                      Louise Bogan         0.734  0.06940
# 21253                                      Brad Fiedel         0.201  0.39100
# 39054                                Story Of The Year         0.254  0.97000
# 15187                                    Pino Donaggio         0.215  0.24200
# 2495                                       Traditional         0.282  0.05950
# 6039                                       Victor Jara         0.544  0.62900
# 4877                   National Philharmonic Orchestra         0.193  0.12300
# 34927  Lil Dicky Featuring Fetty Wap & Rich Homie Quan         0.858  0.69700
# 6348                                        Nick Drake         0.507  0.39000
# 4712                                The Bonzo Dog Band         0.429  0.47300
# 34500                  Jay-Z Featuring Beyonce Knowles         0.759  0.67500
# 23011                                       Paul Davis         0.647  0.68600
# 5876                                   Jerry Goldsmith         0.446  0.07510
# 14051                                 Big Joe Williams         0.452  0.23900
# 13562                                 Big Joe Williams         0.452  0.23900
# 6571                                   Jerry Goldsmith         0.652  0.14700
# 4509                                   Jerry Goldsmith         0.533  0.00804
# 10697                                   Renato Sellani         0.420  0.04640
# 5630                                       McCoy Tyner         0.541  0.17700
#
#        key  loudness  mode  speechiness  acousticness  instrumentalness  \
# 11343    9    -5.081     1       0.1360       0.10100          0.001480
# 4669     3   -24.330     1       0.9170       0.61100          0.000000
# 21253    7   -16.067     1       0.0479       0.88900          0.864000
# 39054    8    -4.635     1       0.0789       0.00015          0.005860
# 15187    0   -15.141     0       0.0398       0.58400          0.936000
# 2495     7   -26.589     1       0.0415       0.99300          0.849000
# 6039    10   -11.324     1       0.1770       0.86700          0.000006
# 4877     2   -16.581     0       0.0397       0.97900          0.881000
# 34927    2    -5.361     1       0.2300       0.11400          0.000000
# 6348     3   -17.218     1       0.0326       0.65700          0.859000
# 4712     7    -9.188     0       0.0310       0.60500          0.000000
# 34500    9    -5.148     0       0.3130       0.22800          0.000000
# 23011    2    -4.247     0       0.0274       0.43200          0.000006
# 5876     9   -21.314     1       0.0434       0.99400          0.677000
# 14051    4   -17.514     0       0.0463       0.68900          0.000195
# 13562    4   -17.514     0       0.0463       0.68900          0.000195
# 6571     5   -18.086     1       0.0675       0.97600          0.000017
# 4509     2   -29.698     1       0.0535       0.99600          0.902000
# 10697    0   -19.573     1       0.0458       0.99400          0.903000
# 5630     3   -19.927     0       0.0493       0.94700          0.901000
#
#        liveness  valence    tempo  duration_s  time_signature  chorus_hit  \
# 11343    0.8740   0.6320  171.578     443.320               4    53.79041
# 4669     0.1060   0.3190  108.734      78.472               5    31.28651
# 21253    0.1110   0.1810   59.801     226.310               4    38.29173
# 39054    0.1410   0.1660   99.963     300.520               4    55.19977
# 15187    0.1460   0.0613  116.234     143.520               4    25.60898
# 2495     0.1070   0.2010   76.620     110.173               4    32.82781
# 6039     0.3470   0.5860  108.040     167.834               4    79.72459
# 4877     0.0848   0.0936   83.204     697.387               4    49.61964
# 34927    0.2240   0.3640   98.012     290.836               4    38.04379
# 6348     0.0613   0.5200  118.805     284.987               4    41.96860
# 4712     0.1380   0.4090  170.416     160.053               4    38.98600
# 34500    0.1500   0.3280   89.642     205.560               4    35.32814
# 23011    0.1330   0.9520  155.697     219.813               4    26.90576
# 5876     0.0751   0.2420   67.952     118.952               3    31.73251
# 14051    0.6820   0.6730   92.399     322.173               4    50.14461
# 13562    0.6820   0.6730   92.399     322.173               4    50.14461
# 6571     0.1480   0.7620   67.854      33.003               4     0.00000
# 4509     0.1220   0.5040  140.340      86.524               4    24.32886
# 10697    0.0921   0.0382  129.695     299.607               3    90.43377
# 5630     0.0794   0.2370   62.656     382.800               4    94.32103
#
#        sections  popularity decade genre
# 11343        16           1    70s  rock
# 4669          4           0    60s   rap
# 21253        10           0    80s  rock
# 39054        13           0    10s  rock
# 15187         9           0    70s  rock
# 2495          7           0    60s  rock
# 6039          7           0    60s   pop
# 4877         30           0    60s  rock
# 34927        13           1    10s   rap
# 6348         11           0    60s   r&b
# 4712          9           0    60s   edm
# 34500         8           1    00s   rap
# 23011        13           1    80s   pop
# 5876          6           0    60s   pop
# 14051        14           0    70s   r&b
# 13562        14           0    70s   r&b
# 6571          2           0    60s   pop
# 4509          5           0    60s   pop
# 10697        13           0    70s   r&b
# 5630         13           0    60s   r&b

# %%
print("Shape: ", songdata.shape)
songdata.dtypes
# Out:
# Shape:  (41099, 20)
# track                object
# artist               object
# danceability        float64
# energy              float64
# key                   int64
# loudness            float64
# mode                  int64
# speechiness         float64
# acousticness        float64
# instrumentalness    float64
# liveness            float64
# valence             float64
# tempo               float64
# duration_s          float64
# time_signature        int64
# chorus_hit          float64
# sections              int64
# popularity            int64
# decade               object
# genre                object
# dtype: object

# %%
songdata.info
# Out:
# <bound method DataFrame.info of                                             track             artist  \
# 11343     ""Cherry Cherry"" from Hot August Night       Neil Diamond
# 4669                           ""Come, Sleep...""       Louise Bogan
# 21253  ""I'll Be Back"" / Police Station & Escape        Brad Fiedel
# 39054          ""Is This My Fate,"" He Asked Them  Story Of The Year
# 15187                     ""Jerry"" To The Rescue      Pino Donaggio
# ...                                           ...                ...
# 34817                                        胜者为王                 窒息
# 31872                                    薔薇と彼女の王子   Heartsrevolution
# 38777                                         还有谁                 窒息
# 32309                                          迷彩       Sheena Ringo
# 40103                                          雏鹰                 窒息
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 11343         0.341  0.9480    9    -5.081     1       0.1360      0.101000
# 4669          0.734  0.0694    3   -24.330     1       0.9170      0.611000
# 21253         0.201  0.3910    7   -16.067     1       0.0479      0.889000
# 39054         0.254  0.9700    8    -4.635     1       0.0789      0.000150
# 15187         0.215  0.2420    0   -15.141     0       0.0398      0.584000
# ...             ...     ...  ...       ...   ...          ...           ...
# 34817         0.516  0.9580    9    -3.439     0       0.1280      0.006720
# 31872         0.499  0.5620    0    -9.957     0       0.0433      0.620000
# 38777         0.468  0.9790    7    -3.041     1       0.1340      0.000765
# 32309         0.176  0.8380    5    -3.938     0       0.0552      0.037000
# 40103         0.314  0.9510   10    -2.593     0       0.0826      0.003130
#
#        instrumentalness  liveness  valence    tempo  duration_s  \
# 11343          0.001480    0.8740   0.6320  171.578     443.320
# 4669           0.000000    0.1060   0.3190  108.734      78.472
# 21253          0.864000    0.1110   0.1810   59.801     226.310
# 39054          0.005860    0.1410   0.1660   99.963     300.520
# 15187          0.936000    0.1460   0.0613  116.234     143.520
# ...                 ...       ...      ...      ...         ...
# 34817          0.034200    0.0679   0.4840  104.717     232.520
# 31872          0.696000    0.1730   0.3750  171.006     148.987
# 38777          0.000012    0.0535   0.4780  170.083     258.600
# 32309          0.007220    0.1110   0.4870  199.282     232.133
# 40103          0.000577    0.3130   0.4290  104.865     318.187
#
#        time_signature  chorus_hit  sections  popularity decade  genre
# 11343               4    53.79041        16           1    70s   rock
# 4669                5    31.28651         4           0    60s    rap
# 21253               4    38.29173        10           0    80s   rock
# 39054               4    55.19977        13           0    10s   rock
# 15187               4    25.60898         9           0    70s   rock
# ...               ...         ...       ...         ...    ...    ...
# 34817               4    41.39266        12           0    10s  latin
# 31872               4    71.83749         6           0    00s    edm
# 38777               4    22.00982        15           0    10s    edm
# 32309               4    61.66259         6           0    00s   rock
# 40103               4    58.35379        14           0    10s   rock
#
# [41099 rows x 20 columns]>

# %% [markdown]
# ### Step 1
# Clean the dataset to remove duplicate songs.
#
# Reference: https://towardsdatascience.com/finding-and-removing-duplicate-rows-in-pandas-dataframe-c6117668631f

# %%
songdata.groupby(['genre']).count()
# Out:
#        track  artist  danceability  energy    key  loudness   mode  \
# genre
# edm     1515    1515          1515    1515   1515      1515   1515
# latin   2870    2870          2870    2870   2870      2870   2870
# pop    16460   16460         16460   16460  16460     16460  16460
# r&b    11040   11040         11040   11040  11040     11040  11040
# rap     2364    2364          2364    2364   2364      2364   2364
# rock    6850    6850          6850    6850   6850      6850   6850
#
#        speechiness  acousticness  instrumentalness  liveness  valence  tempo  \
# genre
# edm           1515          1515              1515      1515     1515   1515
# latin         2870          2870              2870      2870     2870   2870
# pop          16460         16460             16460     16460    16460  16460
# r&b          11040         11040             11040     11040    11040  11040
# rap           2364          2364              2364      2364     2364   2364
# rock          6850          6850              6850      6850     6850   6850
#
#        duration_s  time_signature  chorus_hit  sections  popularity  decade
# genre
# edm          1515            1515        1515      1515        1515    1515
# latin        2870            2870        2870      2870        2870    2870
# pop         16460           16460       16460     16460       16460   16460
# r&b         11040           11040       11040     11040       11040   11040
# rap          2364            2364        2364      2364        2364    2364
# rock         6850            6850        6850      6850        6850    6850

# %% [markdown]
# We can use the _duplicated()_ function to find duplicates in the dataset. As can be seen from the sum, there are 5,765 duplicated rows with the same track variable value.

# %%
songdata.track.duplicated().sum()
# Out:
# 5246

# %% [markdown]
# View duplicate rows:

# %%
songdata.loc[songdata.track.duplicated(), :]
# Out:
#                                track                   artist  danceability  \
# 13562            'Buked and Scorned'         Big Joe Williams         0.452
# 1284                 'Round Midnight  Gerald Wilson Orchestra         0.503
# 6521                 'Round Midnight            Sonny Rollins         0.424
# 34567  (I Can't Get No) Satisfaction                Sky Saxon         0.531
# 11879        (I Know) I'm Losing You               Rare Earth         0.463
# ...                              ...                      ...           ...
# 2799                   Água De Beber     Antônio Carlos Jobim         0.717
# 8656                  Águas De Marco              Elis Regina         0.611
# 24742                 Águas De Março     Antônio Carlos Jobim         0.652
# 20781                 Águas De Março     Antônio Carlos Jobim         0.649
# 22428                     את לי לילה              Zohar Argov         0.388
#
#        energy  key  loudness  mode  speechiness  acousticness  \
# 13562   0.239    4   -17.514     0       0.0463        0.6890
# 1284    0.227    3   -16.926     0       0.0314        0.8440
# 6521    0.205   10   -13.869     0       0.0290        0.9050
# 34567   0.850    2    -5.379     1       0.0415        0.0031
# 11879   0.553    6   -14.648     1       0.0465        0.5730
# ...       ...  ...       ...   ...          ...           ...
# 2799    0.209    4   -20.825     0       0.0519        0.7430
# 8656    0.322    3   -13.666     1       0.2870        0.8020
# 24742   0.377    3   -14.848     1       0.1760        0.8450
# 20781   0.321    3   -16.751     1       0.1280        0.7780
# 22428   0.466   11   -12.746     0       0.0446        0.3750
#
#        instrumentalness  liveness  valence    tempo  duration_s  \
# 13562          0.000195    0.6820    0.673   92.399     322.173
# 1284           0.665000    0.1030    0.208  109.100     312.893
# 6521           0.780000    0.1240    0.164   97.331     239.707
# 34567          0.000000    0.1530    0.739  134.945     236.947
# 11879          0.000037    0.3150    0.715  100.608     215.987
# ...                 ...       ...      ...      ...         ...
# 2799           0.885000    0.0752    0.907  135.681     170.627
# 8656           0.000044    0.1210    0.857  150.686     185.773
# 24742          0.000001    0.1030    0.506  143.767     212.493
# 20781          0.000000    0.0943    0.572  143.719     211.627
# 22428          0.000000    0.0999    0.425  141.879     314.307
#
#        time_signature  chorus_hit  sections  popularity decade genre
# 13562               4    50.14461        14           0    70s   r&b
# 1284                4    26.91597        13           0    60s   r&b
# 6521                4    23.07802        11           0    60s   pop
# 34567               4    40.80212         7           0    00s   pop
# 11879               4    28.63916         9           1    70s   pop
# ...               ...         ...       ...         ...    ...   ...
# 2799                4    45.61740        10           0    60s   pop
# 8656                4    42.88205        10           0    70s   rap
# 24742               4    35.39803        11           0    90s   pop
# 20781               4    35.36344        13           0    80s   pop
# 22428               4    63.49500        15           0    80s   r&b
#
# [5246 rows x 20 columns]

# %% [markdown]
# Finally, to drop the duplicate rows, we can use the _drop_duplicates()_ function to drop the rows with duplicates from the dataframe. We set `keep` to `first` to keep only the first occurrence of the row, and set `inplace=True` to update the original dataframe.

# %%
songdata.drop_duplicates(subset=['track'], keep='first', inplace=True)
print('New shape: ', songdata.shape)
songdata.head()
# Out:
# New shape:  (35853, 20)
#                                             track             artist  \
# 11343     ""Cherry Cherry"" from Hot August Night       Neil Diamond
# 4669                           ""Come, Sleep...""       Louise Bogan
# 21253  ""I'll Be Back"" / Police Station & Escape        Brad Fiedel
# 39054          ""Is This My Fate,"" He Asked Them  Story Of The Year
# 15187                     ""Jerry"" To The Rescue      Pino Donaggio
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 11343         0.341  0.9480    9    -5.081     1       0.1360       0.10100
# 4669          0.734  0.0694    3   -24.330     1       0.9170       0.61100
# 21253         0.201  0.3910    7   -16.067     1       0.0479       0.88900
# 39054         0.254  0.9700    8    -4.635     1       0.0789       0.00015
# 15187         0.215  0.2420    0   -15.141     0       0.0398       0.58400
#
#        instrumentalness  liveness  valence    tempo  duration_s  \
# 11343           0.00148     0.874   0.6320  171.578     443.320
# 4669            0.00000     0.106   0.3190  108.734      78.472
# 21253           0.86400     0.111   0.1810   59.801     226.310
# 39054           0.00586     0.141   0.1660   99.963     300.520
# 15187           0.93600     0.146   0.0613  116.234     143.520
#
#        time_signature  chorus_hit  sections  popularity decade genre
# 11343               4    53.79041        16           1    70s  rock
# 4669                5    31.28651         4           0    60s   rap
# 21253               4    38.29173        10           0    80s  rock
# 39054               4    55.19977        13           0    10s  rock
# 15187               4    25.60898         9           0    70s  rock

# %% [markdown]
# We have about 2945 unique songs. We can probably parse the song name and categorized it by language as well.

# %% [markdown]
# ### Step 2
# Perform exploratory analysis on the acoustic data of the songs.

# %% [markdown]
# > Use the following code to identify other non-English languages in Song Name among the 13070 records

# %%
songdata = songdata.sort_values(["decade"], ascending = (False))
songdata.head(50)
# Out:
#                                                    track  \
# 28366  Concerto for Harpsichord, Strings, and Continu...
# 28022                      Everything's Gonna Be Alright
# 25244                                            Buddy X
# 27829                                           Bucktown
# 28154                                     Personal Jesus
# 24164                                   The Box - Part 2
# 27953                                            Bubbles
# 24419                                    The Boy Is Mine
# 26019                    The Boy Who Destroyed The World
# 25101                                               Bruz
# 26527        I Wanna Sex You Up (From ""New Jack City"")
# 26552                                      Everything Is
# 26627                                  Pero Nunca Me Caí
# 24724                                The British Arrival
# 28625                                      Bruca Maniguá
# 25176                                         Kinky Love
# 27799                                        Brown Sugar
# 28368                           Performance One - Part 1
# 28711                               Brown Mountain Light
# 28075               Everything You Do (You're Sexing Me)
# 26876                                 The Carpenter Shop
# 25695                                 Everything Changes
# 27599                               Everything About You
# 28411                                 The Boomin' System
# 27988                                 Building A Mystery
# 26245                       Petit vaurien - Version rock
# 27546                                         Petit pays
# 28705                                            Kiss Me
# 24171                        Bullet With Butterfly Wings
# 26643                         Everyday Is A Winding Road
# 23451                             Everyone Falls In Love
# 26729                                   Kiss From A Rose
# 27629                             I Wanna Love Like That
# 28718                                       The Bleeding
# 27493         The Bomb! (These Sounds Fall Into My Mind)
# 25876                    The Blood, the Sweat, the Tears
# 26987                                Pete Standing Alone
# 24876                                      Everyotherday
# 28179                                      Buhaina Chant
# 28539              I Wanna Love You (From ""Class Act"")
# 25416                              The Blues Overtook Me
# 25682                           I Wanna Love You Forever
# 26061             Everything (... Is Never Quite Enough)
# 24721                               Everything's Changed
# 28604                                  The Chanukah Song
# 26267                                          Presumida
# 25802                                    Everytime I Cry
# 23609                                        The Courier
# 24878                                Bring out Your Dead
# 23436                                     Bring The Pain
#
#                                   artist  danceability   energy  key  \
# 28366              Johann Sebastian Bach         0.366  0.00757    8
# 28022                  Naughty By Nature         0.883  0.64700   10
# 25244                       Neneh Cherry         0.830  0.58600    5
# 27829                      Smif-N-Wessun         0.769  0.83600    8
# 28154                       Depeche Mode         0.637  0.68200   11
# 24164                            Orbital         0.603  0.72000    9
# 27953                  Parachute Express         0.626  0.25100    2
# 24419                    Brandy & Monica         0.704  0.70700    1
# 26019                                AFI         0.232  0.97800    4
# 25101                  Jan Lundgren Trio         0.555  0.28200   10
# 26527                      Color Me Badd         0.551  0.59100    6
# 26552                 Neutral Milk Hotel         0.528  0.55500    3
# 26627                           Caifanes         0.443  0.78800    2
# 24724                      Randy Edelman         0.161  0.06590    4
# 28625                     Ibrahim Ferrer         0.499  0.37100   10
# 25176                        Pale Saints         0.376  0.27700    1
# 27799                           D'Angelo         0.815  0.36400    8
# 28368                        Terry Riley         0.110  0.16300    7
# 28711                          Tony Rice         0.620  0.47500    7
# 28075       Fiona (Duet With Kip Winger)         0.604  0.81400    1
# 26876            The Bluegrass Cardinals         0.661  0.12100   11
# 25695                     Kathy Troccoli         0.749  0.87400    6
# 27599                       Ugly Kid Joe         0.501  0.80300    1
# 28411                          LL Cool J         0.794  0.53600    0
# 27988                    Sarah McLachlan         0.505  0.51800    2
# 26245                           Dorothée         0.523  0.82300    0
# 27546                      Cesária Evora         0.551  0.48800    4
# 28705           Sixpence None The Richer         0.526  0.74900    3
# 24171              The Smashing Pumpkins         0.404  0.72000   10
# 26643                        Sheryl Crow         0.629  0.67300    6
# 23451              Tanto Metro & Devonte         0.754  0.70200   10
# 26729                               Seal         0.583  0.53200   10
# 27629                      Tony Thompson         0.803  0.55700   10
# 28718                    Cannibal Corpse         0.216  0.98700    1
# 27493                    The Bucketheads         0.832  0.89700    9
# 25876                       Machine Head         0.338  0.97400    4
# 26987                   Boards of Canada         0.778  0.56200    1
# 24876  Or-N-More (Featuring Father M.C.)         0.780  0.72500    1
# 28179   Art Blakey & The Jazz Messengers         0.361  0.50200    9
# 28539                               Jade         0.731  0.70700    0
# 25416                Charlie Musselwhite         0.409  0.82500    7
# 25682                    Jessica Simpson         0.590  0.66600    4
# 26061                         Wasis Diop         0.661  0.61900    8
# 24721                           Lonestar         0.679  0.58000    5
# 28604                       Adam Sandler         0.356  0.50300    9
# 26267                  Los Superclasicos         0.432  0.48600    2
# 25802                        Terri Clark         0.649  0.74700    3
# 23609                      Randy Edelman         0.110  0.31900    8
# 24878                         Strung Out         0.449  0.97600    5
# 23436                         Method Man         0.835  0.45600    6
#
#        loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 28366   -37.867     1       0.0490      0.990000          0.884000    0.0885
# 28022   -14.054     0       0.1970      0.063300          0.000000    0.2540
# 25244    -8.457     1       0.0375      0.083200          0.000042    0.0797
# 27829    -4.150     1       0.2440      0.061800          0.000000    0.1820
# 28154   -11.625     1       0.0366      0.011200          0.023400    0.0473
# 24164   -12.956     0       0.0295      0.007500          0.936000    0.0960
# 27953   -17.876     1       0.0959      0.769000          0.000000    0.0835
# 24419    -6.537     0       0.0391      0.539000          0.001060    0.3180
# 26019    -5.766     0       0.0836      0.000035          0.003950    0.3210
# 25101   -18.685     1       0.0361      0.843000          0.898000    0.6950
# 26527    -8.404     0       0.1200      0.005490          0.000007    0.0416
# 26552   -10.412     1       0.0417      0.005600          0.001420    0.3480
# 26627    -8.716     1       0.0396      0.011000          0.000000    0.2930
# 24724   -26.490     1       0.0438      0.891000          0.939000    0.1000
# 28625   -11.624     1       0.0449      0.836000          0.005570    0.1310
# 25176   -18.291     1       0.0357      0.133000          0.000000    0.0643
# 27799   -11.834     0       0.0890      0.140000          0.025500    0.1210
# 28368   -24.265     0       0.0466      0.844000          0.913000    0.0894
# 28711   -12.226     1       0.0326      0.800000          0.000205    0.2910
# 28075    -9.873     1       0.0286      0.056000          0.000000    0.2900
# 26876   -16.971     1       0.0396      0.873000          0.000000    0.1090
# 25695    -3.981     1       0.0332      0.085300          0.000003    0.0414
# 27599    -8.449     1       0.0547      0.008810          0.000002    0.1070
# 28411   -14.347     1       0.3070      0.012100          0.000002    0.3500
# 27988    -8.601     1       0.0230      0.403000          0.000000    0.1290
# 26245    -7.304     1       0.0324      0.575000          0.023900    0.3710
# 27546   -11.583     0       0.0321      0.804000          0.000000    0.2640
# 28705    -6.964     1       0.0283      0.023000          0.000002    0.0692
# 24171    -9.180     0       0.0626      0.000056          0.836000    0.0466
# 26643    -8.285     1       0.0406      0.041900          0.000036    0.1000
# 23451    -8.033     0       0.0429      0.027500          0.000000    0.0619
# 26729    -7.110     0       0.0309      0.684000          0.000000    0.3060
# 27629    -8.446     0       0.0404      0.151000          0.000008    0.0428
# 28718    -7.370     0       0.0971      0.000004          0.908000    0.0520
# 27493    -5.093     0       0.0377      0.002580          0.591000    0.3860
# 25876    -7.430     1       0.1400      0.000126          0.000302    0.1440
# 26987   -14.082     1       0.0884      0.042900          0.895000    0.1320
# 24876   -10.044     0       0.0439      0.091800          0.000018    0.9090
# 28179   -20.589     1       0.0978      0.761000          0.751000    0.0858
# 28539    -9.790     0       0.0769      0.059600          0.006540    0.2640
# 25416    -5.756     1       0.1060      0.136000          0.004140    0.2050
# 25682    -4.047     0       0.0244      0.156000          0.000000    0.1360
# 26061    -9.728     1       0.0301      0.094300          0.030400    0.0907
# 24721    -7.034     1       0.0238      0.176000          0.001530    0.0944
# 28604    -8.937     1       0.0734      0.766000          0.000003    0.8710
# 26267   -12.500     1       0.0565      0.313000          0.000000    0.0874
# 25802    -4.695     1       0.0300      0.097900          0.000000    0.2940
# 23609   -20.953     1       0.0393      0.265000          0.930000    0.1210
# 24878    -4.882     0       0.0915      0.000474          0.104000    0.3350
# 23436   -10.195     0       0.2660      0.380000          0.003590    0.1600
#
#        valence    tempo  duration_s  time_signature  chorus_hit  sections  \
# 28366   0.3280  182.062     176.000               3    82.57264         9
# 28022   0.7390  101.649     291.867               4    37.66632         8
# 25244   0.6780  102.864     169.000               4    44.17359         8
# 27829   0.6510   88.978     237.720               4    64.95334        11
# 28154   0.7140  129.983     224.907               4    62.14972         6
# 24164   0.6600  140.991     359.586               4    28.64798         8
# 27953   0.6440   78.562     157.400               4    33.12840         7
# 24419   0.7610   93.145     294.787               4    24.71337        15
# 26019   0.5780  163.712     185.360               4    40.38843         7
# 25101   0.6760   98.014     284.533               4    31.95505         8
# 26527   0.4740  201.799     236.947               4    30.51548        13
# 26552   0.8150  110.499     221.467               4    86.07114         6
# 26627   0.4140  145.151     253.027               4    37.29241        12
# 24724   0.0394  109.446     122.907               4    54.41673         5
# 28625   0.6840  110.274     284.320               4    36.61435        15
# 25176   0.3090  178.814     244.240               4    47.49646        11
# 27799   0.7230   84.898     346.267               4   100.55420        13
# 28368   0.0384   73.731    1249.000               4    49.11283        46
# 28711   0.8050  123.936     222.867               4    31.11595         9
# 28075   0.8220  108.766     254.173               4    27.36302        12
# 26876   0.5210  119.109     194.667               4    32.89857        12
# 25695   0.7800  117.776     262.200               4    20.56071        10
# 27599   0.7380  122.458     255.160               4    35.68415         8
# 28411   0.5280   96.043     223.640               4    23.58620        11
# 27988   0.4720   81.019     247.307               4    40.65651        10
# 26245   0.9310  175.463     226.493               4    42.74889        12
# 27546   0.8550  156.152     224.507               4    26.38963        10
# 28705   0.4210   99.982     208.680               4    37.65360         9
# 24171   0.4750  121.649     258.467               4    49.99463         9
# 26643   0.7170  112.955     256.000               4    27.21214        11
# 23451   0.7360   95.998     228.360               4    40.40180        13
# 26729   0.2230  131.741     288.427               3    24.39038        15
# 27629   0.7770   89.134     307.067               4    39.81558        12
# 28718   0.1990   93.803     259.680               4    19.21569        14
# 27493   0.7580  125.888     484.533               4    76.25068        18
# 25876   0.3980  139.605     251.000               4    29.27072        12
# 26987   0.4160  110.360     367.720               4    36.04717        14
# 24876   0.8310  113.311     232.800               4    20.69562        12
# 28179   0.1640  159.437     630.627               4    34.23463        22
# 28539   0.8380  200.306     271.400               4    38.14043        12
# 25416   0.7420  146.516     282.707               4    50.50836        14
# 25682   0.0743  104.042     263.800               4    55.29855        10
# 26061   0.2710  142.941     272.040               4    78.66850         9
# 24721   0.4290  104.357     233.773               4    41.01474        13
# 28604   0.3310   88.816     223.947               4    28.32593        11
# 26267   0.9620  204.932     118.707               4    39.71916         6
# 25802   0.5250  116.400     227.387               4    36.27157        11
# 23609   0.1310   83.743     149.667               3    26.06939        10
# 24878   0.4090  115.345     169.720               4    55.91813         8
# 23436   0.2240  101.889     189.760               4    42.58583         9
#
#        popularity decade  genre
# 28366           0    90s    edm
# 28022           1    90s    r&b
# 25244           1    90s    pop
# 27829           1    90s    rap
# 28154           1    90s    pop
# 24164           0    90s    r&b
# 27953           0    90s    pop
# 24419           1    90s    r&b
# 26019           0    90s   rock
# 25101           0    90s    r&b
# 26527           1    90s    edm
# 26552           0    90s    pop
# 26627           0    90s    r&b
# 24724           0    90s   rock
# 28625           0    90s    r&b
# 25176           0    90s    edm
# 27799           1    90s    r&b
# 28368           0    90s   rock
# 28711           0    90s    pop
# 28075           1    90s    r&b
# 26876           0    90s    pop
# 25695           1    90s    r&b
# 27599           1    90s    r&b
# 28411           1    90s    rap
# 27988           1    90s    r&b
# 26245           0    90s    edm
# 27546           0    90s    pop
# 28705           1    90s    pop
# 24171           1    90s    r&b
# 26643           1    90s    r&b
# 23451           1    90s    pop
# 26729           1    90s    r&b
# 27629           1    90s    r&b
# 28718           0    90s   rock
# 27493           1    90s    r&b
# 25876           0    90s   rock
# 26987           0    90s    r&b
# 24876           1    90s    pop
# 28179           0    90s    r&b
# 28539           1    90s    edm
# 25416           0    90s    r&b
# 25682           1    90s    r&b
# 26061           0    90s    r&b
# 24721           1    90s    pop
# 28604           1    90s   rock
# 26267           0    90s    edm
# 25802           1    90s    pop
# 23609           0    90s   rock
# 24878           0    90s  latin
# 23436           1    90s    rap

# %%
# Summary Statistics for numeric Variables
songdata.describe().round(3)
# Out:
#        danceability     energy        key   loudness       mode  speechiness  \
# count     35853.000  35853.000  35853.000  35853.000  35853.000    35853.000
# mean          0.537      0.578      5.198    -10.308      0.691        0.074
# std           0.179      0.255      3.534      5.386      0.462        0.088
# min           0.000      0.000      0.000    -49.253      0.000        0.000
# 25%           0.416      0.392      2.000    -12.930      0.000        0.034
# 50%           0.549      0.599      5.000     -9.315      1.000        0.044
# 75%           0.668      0.787      8.000     -6.410      1.000        0.071
# max           0.988      1.000     11.000      3.744      1.000        0.960
#
#        acousticness  instrumentalness   liveness    valence      tempo  \
# count     35853.000         35853.000  35853.000  35853.000  35853.000
# mean          0.369             0.162      0.203      0.540    119.282
# std           0.341             0.309      0.174      0.269     29.221
# min           0.000             0.000      0.013      0.000      0.000
# 25%           0.039             0.000      0.094      0.326     97.185
# 50%           0.267             0.000      0.132      0.556    117.391
# 75%           0.686             0.082      0.263      0.767    136.606
# max           0.996             1.000      0.999      0.996    241.423
#
#        duration_s  time_signature  chorus_hit   sections  popularity
# count   35853.000       35853.000   35853.000  35853.000   35853.000
# mean      235.413           3.891      40.198     10.494       0.473
# std       122.664           0.431      19.180      5.012       0.499
# min        15.168           0.000       0.000      0.000       0.000
# 25%       172.213           4.000      27.573      8.000       0.000
# 50%       217.627           4.000      35.895     10.000       0.000
# 75%       267.093           4.000      47.777     12.000       1.000
# max      4170.227           5.000     433.182    169.000       1.000

# %%
songdata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 35853 entries, 28366 to 34145
# Data columns (total 20 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   track             35853 non-null  object
#  1   artist            35853 non-null  object
#  2   danceability      35853 non-null  float64
#  3   energy            35853 non-null  float64
#  4   key               35853 non-null  int64
#  5   loudness          35853 non-null  float64
#  6   mode              35853 non-null  int64
#  7   speechiness       35853 non-null  float64
#  8   acousticness      35853 non-null  float64
#  9   instrumentalness  35853 non-null  float64
#  10  liveness          35853 non-null  float64
#  11  valence           35853 non-null  float64
#  12  tempo             35853 non-null  float64
#  13  duration_s        35853 non-null  float64
#  14  time_signature    35853 non-null  int64
#  15  chorus_hit        35853 non-null  float64
#  16  sections          35853 non-null  int64
#  17  popularity        35853 non-null  int64
#  18  decade            35853 non-null  object
#  19  genre             35853 non-null  object
# dtypes: float64(11), int64(5), object(4)
# memory usage: 5.7+ MB

# %% [markdown]
# ### Since no clear correlation is found on univariate linear regression, we use Feedforward Neural Network (Multi-layer Perceptron)
#
#
# ... results are as follows

# %% [markdown]
# MLPClassifier predicts classes that inputs fall into, and therefore we need to classify the song_popularity values and label encode them.

# %%
popularity_class = []

#for var in songdata['song_popularity']:
#   if(0 <= var and var <= 50):
#        popularity_class.append(0)
#    else:
#        popularity_class.append(1)

#songdata['popularity_class'] = popularity_class
#songdata.head()

from sklearn.preprocessing import LabelEncoder

# label encoding song_popularity
songdata['genre'] = LabelEncoder().fit_transform(songdata['genre'])
songdata.head()
# Out:
#                                             track             artist  \
# 11343     ""Cherry Cherry"" from Hot August Night       Neil Diamond
# 4669                           ""Come, Sleep...""       Louise Bogan
# 21253  ""I'll Be Back"" / Police Station & Escape        Brad Fiedel
# 39054          ""Is This My Fate,"" He Asked Them  Story Of The Year
# 15187                     ""Jerry"" To The Rescue      Pino Donaggio
#
#        danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 11343         0.341  0.9480    9    -5.081     1       0.1360       0.10100
# 4669          0.734  0.0694    3   -24.330     1       0.9170       0.61100
# 21253         0.201  0.3910    7   -16.067     1       0.0479       0.88900
# 39054         0.254  0.9700    8    -4.635     1       0.0789       0.00015
# 15187         0.215  0.2420    0   -15.141     0       0.0398       0.58400
#
#        instrumentalness  liveness  valence    tempo  duration_s  \
# 11343           0.00148     0.874   0.6320  171.578     443.320
# 4669            0.00000     0.106   0.3190  108.734      78.472
# 21253           0.86400     0.111   0.1810   59.801     226.310
# 39054           0.00586     0.141   0.1660   99.963     300.520
# 15187           0.93600     0.146   0.0613  116.234     143.520
#
#        time_signature  chorus_hit  sections  popularity decade  genre
# 11343               4    53.79041        16           1    70s      5
# 4669                5    31.28651         4           0    60s      4
# 21253               4    38.29173        10           0    80s      5
# 39054               4    55.19977        13           0    10s      5
# 15187               4    25.60898         9           0    70s      5

# %% [markdown]
# We now need to scale the predictor variables so that they can be used together to predict the popularity_class.

# %%
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import MinMaxScaler

songdata[['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'tempo', 'time_signature', 'valence', 'mode', 'speechiness', 'chorus_hit', 'sections', 'duration_s']] = MinMaxScaler().fit_transform(songdata[['acousticness', 'danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'tempo', 'time_signature', 'valence', 'mode', 'speechiness', 'chorus_hit', 'sections', 'duration_s']])

songdata.drop(columns=['popularity', 'track', 'artist', 'decade', 'time_signature', 'sections', 'acousticness', 'valence', 'mode', 'chorus_hit'], inplace=True)
songdata.describe()
# Out:
#        danceability        energy           key      loudness   speechiness  \
# count  35853.000000  35853.000000  35853.000000  35853.000000  35853.000000
# mean       0.543350      0.577640      5.198393      0.734854      0.077077
# std        0.181269      0.254805      3.533529      0.101619      0.091748
# min        0.000000      0.000000      0.000000      0.000000      0.000000
# 25%        0.421053      0.391847      2.000000      0.685378      0.035313
# 50%        0.555668      0.598899      5.000000      0.753590      0.045625
# 75%        0.676113      0.786947      8.000000      0.808404      0.073958
# max        1.000000      1.000000     11.000000      1.000000      1.000000
#
#        instrumentalness      liveness         tempo    duration_s  \
# count      35853.000000  35853.000000  35853.000000  35853.000000
# mean           0.161870      0.192366      0.494077      0.053006
# std            0.309411      0.176929      0.121035      0.029522
# min            0.000000      0.000000      0.000000      0.000000
# 25%            0.000000      0.082252      0.402551      0.037796
# 50%            0.000143      0.120690      0.486246      0.048726
# 75%            0.082000      0.253550      0.565837      0.060631
# max            1.000000      1.000000      1.000000      1.000000
#
#               genre
# count  35853.000000
# mean       2.755167
# std        1.301983
# min        0.000000
# 25%        2.000000
# 50%        2.000000
# 75%        3.000000
# max        5.000000

# %%
songdata['genre'].value_counts()
# Out:
# 2    14247
# 3     9499
# 5     6157
# 1     2497
# 4     2127
# 0     1326
# Name: genre, dtype: int64

# %% [markdown]
# We note that the numbers of each songs per category are different. For example, there are 14247 songs in the Pop genre, whereas there are only 1326 songs in the EDM genre. Although using a Train/Test model would help to obtain random sampling of data, as there is a huge difference in sample size between song categories, we run the risk of introducing a significant sampling bias.
#
# Hence, we use Stratified Sampling Technique, which would help to eliminate the biasness of the selection of data.
#
# Source: https://medium.com/@IrekponorVictor/creating-an-unbiased-test-set-for-your-model-using-stratified-sampling-technique-672b778022d5

# %%
# importing StratifiedShuffleSplit
from sklearn.model_selection import StratifiedShuffleSplit

split = StratifiedShuffleSplit(n_splits=1, test_size=0.20)

for train_index, test_index in split.split(songdata, songdata['genre']):
     train_set, test_set = songdata.iloc[train_index], songdata.iloc[test_index]

# after obtaining train/test set, proceed to split train into X and y train set, and test into x and y test set
y_train = pd.DataFrame(train_set['genre'])
x_train = train_set
x_train = x_train.drop(columns=['genre'])

y_test = pd.DataFrame(test_set['genre'])
x_test = test_set
x_test = x_test.drop(columns=['genre'])

# %% [markdown]
# Check how many songs in each genre there are in train/test set

# %%
y_train.value_counts
# Out:
# <bound method DataFrame.value_counts of        genre
# 11991      5
# 21896      3
# 32569      1
# 6588       5
# 17970      3
# ...      ...
# 22969      1
# 8156       5
# 22985      3
# 12583      2
# 40351      4
#
# [28682 rows x 1 columns]>

# %%
print(len(y_train))
print((int)(np.ceil(10**6 / len(y_train))))
# Out:
# 28682
# 35

# %%
y_test.value_counts()
# Out:
# genre
# 2        2850
# 3        1900
# 5        1232
# 1         499
# 4         425
# 0         265
# dtype: int64

# %% [markdown]
# After obtaining Train/Test data, use MLPClassifier

# %% [markdown]
# Try plotting the correlation matrix.

# %%
def accuracy(confusion_matrix):
   diagonal_sum = confusion_matrix.trace()
   sum_of_all_elements = confusion_matrix.sum()
   return diagonal_sum / sum_of_all_elements

#y_train_minmax = MinMaxScaler().fit_transform(y_train)
#y_train_minmax = y_train_minmax.astype('int')
#y_train_normalized = (y_train-y_train.min())/(y_train.max()-y_train.min())

#Initializing the MLPClassifier
classifier = MLPClassifier(hidden_layer_sizes=(400, 300, 250, 100, 50), max_iter=3000,
                           activation = 'relu', solver='sgd', learning_rate='adaptive', learning_rate_init=0.0001,
                           momentum=0.9, batch_size=6, random_state=1)

classifier.fit(x_train, y_train.values.ravel())
y_pred = classifier.predict(x_train)

#Importing Confusion Matrix
from sklearn.metrics import confusion_matrix
#Comparing the predictions against the actual observations in y_val
cm = confusion_matrix(y_pred, y_train)

#Printing the accuracy
print("Accuracy of MLPClassifier : ", accuracy(cm))
# Out:
# Accuracy of MLPClassifier :  0.9911442716686424

# %%
sb.heatmap(cm, annot=True, fmt=".0f", annot_kws={"size":18})

# %% [markdown]
# Check the accuracy on the test data.

# %%
# scale the response variable for test and predict
#y_test_minmax = MinMaxScaler().fit_transform(y_test)
#y_test_minmax = y_test_minmax.astype('int64')
#y_test_normalized = (y_test-y_test.min())/(y_test.max()-y_test.min())
y_test_pred = classifier.predict(x_test)

cm = confusion_matrix(y_test_pred, y_test)

# print accuracy
print('Accuracy of MLPClassifier on test data :', accuracy(cm))
# Out:
# Accuracy of MLPClassifier on test data : 0.9813136243201785

# %% [markdown]
# Save model with pickle

# %%
import pickle

filename = "batch_size_6_maxiter3000_refinedpredictors.sav"
pickle.dump(classifier, open(filename, 'wb'))

# %%
import pickle

filename = "batch_size_6_maxiter3000_refinedpredictors.sav"
loaded_model = pickle.load(open(filename, 'rb'))

# %% [markdown]
# Verification with new dataset

# %%
validationdata = pd.read_csv('data/genres_v2.csv', low_memory=False)
validationdata.drop(columns=['type', 'id', 'uri', 'track_href', 'analysis_url', 'time_signature', 'Unnamed: 0', 'title', 'acousticness', 'valence', 'mode'], inplace=True)
validationdata = validationdata.loc[validationdata['genre'].isin(['Pop', 'RnB', 'Rap'])]
validationdata.drop_duplicates(subset=['song_name'], keep='first')

for index_label, row_series in validationdata.iterrows():
    if validationdata.at[index_label , 'genre'] == 'Pop':
        validationdata.at[index_label , 'genre'] = 2
    elif validationdata.at[index_label , 'genre'] == 'RnB':
        validationdata.at[index_label , 'genre'] = 3
    elif validationdata.at[index_label , 'genre'] == 'Rap':
        validationdata.at[index_label , 'genre'] = 4

validationdata['genre'] = pd.to_numeric(validationdata['genre'])
validationdata.head(50000)
# Out:
#        danceability  energy  key  loudness  speechiness  instrumentalness  \
# 14089         0.745   0.561    0    -4.869       0.0807          0.000000
# 14090         0.837   0.364    8   -11.713       0.2760          0.000000
# 14091         0.834   0.730    8    -3.714       0.2220          0.000000
# 14092         0.598   0.427    7    -8.764       0.0317          0.000006
# 14093         0.763   0.628   11    -5.850       0.0500          0.000000
# ...             ...     ...  ...       ...          ...               ...
# 18492         0.486   0.617    5    -7.115       0.0287          0.000003
# 18493         0.572   0.385    7    -6.362       0.0308          0.000000
# 18494         0.781   0.445    2    -6.061       0.0295          0.000000
# 18495         0.620   0.574    5    -7.788       0.0479          0.000000
# 18496         0.556   0.864    3    -5.870       0.0584          0.000000
#
#        liveness    tempo  duration_ms  genre            song_name
# 14089     0.133   77.557       248431      4                Empty
# 14090     0.271  123.984       213594      4         MIDDLE CHILD
# 14091     0.124  155.008       312820      4           SICKO MODE
# 14092     0.210   76.469       175721      4  HIGHEST IN THE ROOM
# 14093     0.114  140.958       190557      4     BUTTERFLY EFFECT
# ...         ...      ...          ...    ...                  ...
# 18492     0.109  138.015       242373      2         Viva La Vida
# 18493     0.231  191.598       215733      2              Shallow
# 18494     0.184  157.996       281560      2    Thinking out Loud
# 18495     0.190  200.046       250173      2       1-800-273-8255
# 18496     0.209  210.286       216880      2           In the End
#
# [4408 rows x 11 columns]

# %%
## converting duration_ms to duration_s as duration_s was used in original dataset
validationdata["duration_ms"] = validationdata["duration_ms"]/1000
validationdata.rename(columns={"duration_ms":"duration_s"},inplace=True)

validationdata[['danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'tempo', 'speechiness', 'duration_s']] = MinMaxScaler().fit_transform(validationdata[['danceability', 'energy', 'instrumentalness', 'liveness', 'loudness', 'tempo', 'speechiness', 'duration_s']])
validationdata.drop(columns=['song_name'], inplace=True)

response = pd.DataFrame(validationdata['genre'])
predictor = validationdata
predictor = validationdata.drop(columns=['genre'])

validation_pred = classifier.predict(predictor)
cm = confusion_matrix(validation_pred, response)

# print accuracy
print('Accuracy of MLPClassifier on test data :', accuracy(cm))

sb.heatmap(cm, annot=True, fmt=".0f", annot_kws={"size":18})
# Out:
# Accuracy of MLPClassifier on test data : 0.4147005444646098
